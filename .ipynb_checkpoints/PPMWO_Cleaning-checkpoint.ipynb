# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Phase 1 : Import, Drop Columns, Add Columns

# %% [markdown]
# ## Read the file

# %% [markdown]
# ### Main file

# %%
df = pd.read_excel("./PPM2.xlsx")
row = len(df)
col = len(df.columns)
print("No. of Rows:" + str(row))
print("No. of Columns:" + str(col))
df.head()
# Out:
# No. of Rows:55324
# No. of Columns:25
#    Flag      WO       Status  \
# 0   3.0  252276    Scheduled
# 1   3.0  252275    Scheduled
# 2   0.0  252274  In Progress
# 3   3.0  252273    Scheduled
# 4   3.0  252272    Scheduled
#
#                                          Description Work Type   Assigned To  \
# 0    Weekly Legionella Prevention Checklist West Bay       PPM  RLN-SOFT WSB
# 1       Weekly Legionella Prevention Checklist WAKRA       PPM  RLS-SOFT AWK
# 2  Weekly Legionella Prevention Checklist Umma Gh...       PPM  RLS-SOFT UMG
# 3         Weekly Legionella Prevention Checklist RBF       PPM  RLS-SOFT RBF
# 4        Weekly Legionella Prevention Checklist OQBA       PPM  RLS-SOFT OBN
#
#    Priority                          Location Sign Off Notes  Subject  ...  \
# 0       NaN  ACIFM/M/RED LINE/M001/01/RNST030            NaN  RNST030  ...
# 1       NaN  ACIFM/M/RED LINE/M004/01/RSST070            NaN  RSST070  ...
# 2       NaN  ACIFM/M/RED LINE/M003/01/RSST020            NaN  RSST020  ...
# 3       NaN  ACIFM/M/RED LINE/M004/01/RSST060            NaN  RSST060  ...
# 4       NaN  ACIFM/M/RED LINE/M003/01/RSST040            NaN  RSST040  ...
#
#   Department Action Parent Work Order     Actual Start / Time  \
# 0        NaN    NaN               NaN                     NaT
# 1        NaN    NaN               NaN                     NaT
# 2        NaN    NaN               NaN 2020-06-11 05:02:13.233
# 3        NaN    NaN               NaN                     NaT
# 4        NaN    NaN               NaN                     NaT
#
#    Actual Completion Date / Time Downtime  Duration  On Hold Reason Done By  \
# 0                            NaT      NaN       NaN             NaN     NaN
# 1                            NaT      NaN       NaN             NaN     NaN
# 2                            NaT      NaN       NaN             NaN     NaN
# 3                            NaT      NaN       NaN             NaN     NaN
# 4                            NaT      NaN       NaN             NaN     NaN
#
#                Entered By
# 0  Muhammad Khalid Shahab
# 1  Muhammad Khalid Shahab
# 2  Muhammad Khalid Shahab
# 3  Muhammad Khalid Shahab
# 4  Muhammad Khalid Shahab
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Reference files

# %%
#Location References
dfLocation = pd.read_excel("./Ref.xlsx", "Location")
dfLocation.head()
# Out:
#       Code                     Station       Line
# 0  BSEE052  Blue Line Other Structures  Blue Line
# 1  BSSB050  Blue Line Other Structures  Blue Line
# 2  BSSB051  Blue Line Other Structures  Blue Line
# 3  BST1050  Blue Line Other Structures  Blue Line
# 4  BST2050  Blue Line Other Structures  Blue Line

# %%
#Department References
dfDepartment = pd.read_excel("./Ref.xlsx", "Department")
dfDepartment.head()
# Out:
#   Department   Department 2
# 0        fls            FLS
# 1       mech     Mechanical
# 2       elec     Electrical
# 3       soft  Soft Services
# 4       chil        Chiller

# %%
#Frequency Refertences
dfFrequency = pd.read_excel("./Ref.xlsx", "Frequency")
dfFrequency.head()
# Out:
#   FreqRef      Frequency
# 0    semi  Semi-Annually
# 1     -sa  Semi-Annually
# 2  annual       Annually
# 3    quar      Quarterly
# 4   month        Monthly

# %%
#System Refertences
dfSystem = pd.read_excel("./Ref.xlsx", "System")
dfSystem.head()
# Out:
#     SysRef   System
# 0     fahu     FAHU
# 1  ac chlr  AC CHLR
# 2     accu     ACCU
# 3      acu      ACU
# 4      ahu      AHU

# %% [markdown]
# ## Drop unnecessary columns

# %%
try :
    del df['Flag']
except : 
    print('Column Deleted')
    
row = len(df)
col = len(df.columns)
print("No. of Rows:" + str(row))
print("No. of Columns:" + str(col))
# Out:
# No. of Rows:55324
# No. of Columns:24

# %% [markdown]
# ## Create additional columns

# %% [markdown]
# ### Adding Status 2 & 3 Columns

# %%
def getStatus(txtFrom) :
    if "Scheduled" in txtFrom :
        return "Open"
    elif "In Progress" in txtFrom :
        return "Open"
    elif "New" in txtFrom :
        return "Open"
    elif "On Hold" in txtFrom :
        return "On Hold"
    elif "Closed" in txtFrom :
        return "Closed"
    elif "Not Done" in txtFrom :
        return "Closed"
    elif "Rejected" in txtFrom :
        return "Closed"
    else : return "NA"
    
def getStatus2(txtFrom) :
    if "On Hold" in txtFrom :
        return "Open"
    else : return txtFrom

df['Status 2'] = df['Status'].apply(lambda x: getStatus(x))
df['Status 3'] = df['Status 2'].apply(lambda x: getStatus2(x))

row = len(df)
col = len(df.columns)
print("No. of Rows:" + str(row))
print("No. of Columns:" + str(col))

df[['WO','Status','Status 2','Status 3']].head()
# Out:
# No. of Rows:55324
# No. of Columns:26
#        WO       Status Status 2 Status 3
# 0  252276    Scheduled     Open     Open
# 1  252275    Scheduled     Open     Open
# 2  252274  In Progress     Open     Open
# 3  252273    Scheduled     Open     Open
# 4  252272    Scheduled     Open     Open

# %% [markdown]
# ### Adding Line and Station Columns

# %%
def getInput(listOfRef, txtFrom) :
    #listOfRef = dfLocation items
    #txtFrom = df current index

    for curRef in listOfRef :
        if curRef in txtFrom :
            return curRef
    return "not available"

df['Code'] = df['Location'].apply(lambda x: getInput(dfLocation['Code'], x))
dfWithLocation = pd.merge(df, dfLocation)

row = len(df)
col = len(df.columns)
print("Original No. of Rows:" + str(row))
print("Original No. of Columns:" + str(col))
print("-------------------------------------")
rowN = len(dfWithLocation)
colN = len(dfWithLocation.columns)
print("New No. of Rows:" + str(rowN))
print("New No. of Columns:" + str(colN))
print("-------------------------------------")
rowD = rowN - row
colD = colN - col
print("Difference in No. of Rows:" + str(rowD))
print("Difference in No. of Columns:" + str(colD))

dfWithLocation[['WO','Location','Code','Line','Station']].head()

#test = dfWithLocation.loc[dfWithLocation['']=="mech"]
#test[['WO','Assigned To','Department','Department 2']].head(100)
# Out:
# Original No. of Rows:55324
# Original No. of Columns:27
# -------------------------------------
# New No. of Rows:55324
# New No. of Columns:29
# -------------------------------------
# Difference in No. of Rows:0
# Difference in No. of Columns:2
#        WO                                      Location     Code      Line  \
# 0  252276              ACIFM/M/RED LINE/M001/01/RNST030  RNST030  Red Line
# 1  250287  ACIFM/M/RED LINE/M001/01/RNST030/Level E/R18  RNST030  Red Line
# 2  250286  ACIFM/M/RED LINE/M001/01/RNST030/Level E/R18  RNST030  Red Line
# 3  250285  ACIFM/M/RED LINE/M001/01/RNST030/Level E/R18  RNST030  Red Line
# 4  250284  ACIFM/M/RED LINE/M001/01/RNST030/Level E/R14  RNST030  Red Line
#
#     Station
# 0  West Bay
# 1  West Bay
# 2  West Bay
# 3  West Bay
# 4  West Bay

# %% [markdown]
# ### Adding Frequency Column

# %%
#Fill Empty Task Field based on Frequency
dfWithLocation['Task/Work Subject Group'] = dfWithLocation['Task/Work Subject Group'].fillna("Annual")

dfWithLocation['Task/Work Subject Group'] = dfWithLocation['Task/Work Subject Group'].str.lower()

def getInput(listOfRef, txtFrom) :
    for curRef in listOfRef :
        if curRef in txtFrom :
            return curRef.lower()
    return "not available"


dfWithLocation['FreqRef'] = dfWithLocation['Task/Work Subject Group'].apply(lambda x: getInput(dfFrequency['FreqRef'], x))
dfWithLocation = pd.merge(dfWithLocation, dfFrequency)

row = len(df)
col = len(df.columns)
print("Original No. of Rows:" + str(row))
print("Original No. of Columns:" + str(col))
print("-------------------------------------")
rowN = len(dfWithLocation)
colN = len(dfWithLocation.columns)
print("New No. of Rows:" + str(rowN))
print("New No. of Columns:" + str(colN))
print("-------------------------------------")
rowD = rowN - row
colD = colN - col
print("Difference in No. of Rows:" + str(rowD))
print("Difference in No. of Columns:" + str(colD))

#Drop Reference
try :
    del dfWithLocation['FreqRef']
except : 
    print('*****Ref Column Deleted******')

dfWithLocation[['WO','Task/Work Subject Group','Frequency']].head()
# Out:
# Original No. of Rows:55324
# Original No. of Columns:27
# -------------------------------------
# New No. of Rows:55324
# New No. of Columns:31
# -------------------------------------
# Difference in No. of Rows:0
# Difference in No. of Columns:4
#        WO    Task/Work Subject Group Frequency
# 0  252276  acifm-leg-weekly-west bay    Weekly
# 1  250253            weekly-crao-wby    Weekly
# 2  250252            weekly-crac-wby    Weekly
# 3  250251            weekly-chwp-wby    Weekly
# 4  250250             weekly-ahu-wby    Weekly

# %% [markdown]
# ### Adding System Column

# %%
def getInput(listOfRef, txtFrom) :
    for curRef in listOfRef :
        if curRef in txtFrom :
            return curRef.lower()
    return "not available"
    

dfWithLocation['SysRef'] = dfWithLocation['Task/Work Subject Group'].apply(lambda x: getInput(dfSystem['SysRef'], x))
dfWithLocation = pd.merge(dfWithLocation, dfSystem)

row = len(df)
col = len(df.columns)
print("Original No. of Rows:" + str(row))
print("Original No. of Columns:" + str(col))
print("-------------------------------------")
rowN = len(dfWithLocation)
colN = len(dfWithLocation.columns)
print("New No. of Rows:" + str(rowN))
print("New No. of Columns:" + str(colN))
print("-------------------------------------")
rowD = rowN - row
colD = colN - col
print("Difference in No. of Rows:" + str(rowD))
print("Difference in No. of Columns:" + str(colD))

#Drop Reference
try :
    del dfWithLocation['SysRef']
except : 
    print('*****Ref Column Deleted******')

dfWithLocation[['WO','Task/Work Subject Group','System']].head(3000)
# Out:
# Original No. of Rows:55324
# Original No. of Columns:27
# -------------------------------------
# New No. of Rows:55324
# New No. of Columns:32
# -------------------------------------
# Difference in No. of Rows:0
# Difference in No. of Columns:5
#           WO          Task/Work Subject Group         System
# 0     252276        acifm-leg-weekly-west bay  not available
# 1     252275           acifm-leg-weekly-wakra  not available
# 2     252274  acifm-leg-weekly-umm ghuwailina  not available
# 3     252273             acifm-leg-weekly-rbf  not available
# 4     252272            acifm-leg-weekly-oqba  not available
# ...      ...                              ...            ...
# 2995  105044          acifm-crac-monthly-m009      CRAC/CRAO
# 2996  141221          acifm-crac-monthly-m006      CRAC/CRAO
# 2997  141220          acifm-crac-monthly-m006      CRAC/CRAO
# 2998  141219          acifm-crac-monthly-m006      CRAC/CRAO
# 2999  141218          acifm-crac-monthly-m006      CRAC/CRAO
#
# [3000 rows x 3 columns]

# %% [markdown]
# # Phase 2 : Formating and Validation

# %% [markdown]
# ## Check for Null and Supply Data

# %% [markdown]
# ### Supply empty Department Field

# %%
nullRows = dfWithLocation['Department'].isna().sum()
print("Department Initial Null count: " + str(nullRows))
nullRows2 = dfWithLocation['Assigned To'].isna().sum()
print("Assigned To Initial Null count: " + str(nullRows2))

#Fill empty Assigned To Field
#dfWithLocation['Department'].fillna(dfWithLocation['Assigned To'], inplace=True) -- For CM

dfWithLocation['Assigned To'] = dfWithLocation['Assigned To'].str.lower()

def checkDept(txtFrom, listOfRef):
    for curRef in listOfRef :
        if curRef in txtFrom :
            return curRef.lower()
    return "not available"

        
dfWithLocation['Department'] = dfWithLocation['Assigned To'] \
.apply(lambda x: checkDept(x, dfDepartment['Department']))

dfWithLocation = pd.merge(dfWithLocation, dfDepartment)

#dfWithLocation['Department'] = dfWithLocation['Department'].apply(lambda x: dfDepartment.loc[x['Department'] == dfDepartment['Department']])

#dfWithLocation['Department 2'] = dfDepartment.loc[dfDepartment['Department'] == dfWithLocation['Department'],['Department 2']]

nullRows2 = dfWithLocation['Department'].isna().sum()
print("After supplying Null count: " + str(nullRows2))

#dfWithLocation[['WO','Assigned To','Department','Department 2']].head(100)
#dfWithLocation.loc[dfWithLocation['Department']=="mech"]
# Out:
# Department Initial Null count: 16407
# Assigned To Initial Null count: 0
# After supplying Null count: 0

# %% [markdown]
# ### Department Cross Checking

# %%
test = dfWithLocation.loc[dfWithLocation['Department']=="mech"]
test[['WO','Assigned To','Department','Department 2']].head(100)
# Out:
#            WO           Assigned To Department Department 2
# 24298  224380          rln-mech kat       mech   Mechanical
# 24299  250255          rln-mech wsb       mech   Mechanical
# 24300  250321         rln-mech decc       mech   Mechanical
# 24301  233414          rln-mech cor       mech   Mechanical
# 24302  220391          rln-mech alq       mech   Mechanical
# ...       ...                   ...        ...          ...
# 24393  126458  acifm mech  al sudan       mech   Mechanical
# 24394  126457  acifm mech  al sudan       mech   Mechanical
# 24395  126456  acifm mech  al sudan       mech   Mechanical
# 24396  126455  acifm mech  al sudan       mech   Mechanical
# 24397  126454  acifm mech  al sudan       mech   Mechanical
#
# [100 rows x 4 columns]

# %% [markdown]
# ### Covert Date format to m/d/yyyy

# %%
# try :
#     dfWithLocation['Planned Start'] = pd.to_datetime(dfWithLocation['Planned Start'], format='%Y%m%d').dt.strftime('%m/%d/%Y')
#     dfWithLocation['Raised Date'] = pd.to_datetime(dfWithLocation['Raised Date'], format='%Y%m%d').dt.strftime('%m/%d/%Y')
#     dfWithLocation['Actual Completion Date / Time'] = pd.to_datetime(dfWithLocation['Actual Completion Date / Time'], \
#                                                                      format='%Y%m%d').dt.strftime('%m/%d/%Y')
# except :
#     print("***Formated Already")
    
# dfWithLocation['Planned Start'] = dfWithLocation['Planned Start'].astype('datetime64[ns]')
# dfWithLocation['Raised Date'] = dfWithLocation['Raised Date'].astype('datetime64[ns]')
# dfWithLocation['Actual Completion Date / Time'] = dfWithLocation['Actual Completion Date / Time'].astype('datetime64[ns]')

# dfWithLocation[['WO','Planned Start','Raised Date','Actual Completion Date / Time']].head(20)

# %% [markdown]
# # Phase 3 : Arrangement, Order and Export

# %% [markdown]
# ### Column Re-order

# %%
rowN = len(dfWithLocation)
colN = len(dfWithLocation.columns)
print("New No. of Rows:" + str(rowN))
print("New No. of Columns:" + str(colN))

row = len(dfWithLocation)
#dfComplete = dfWithLocation[['WO','Code','Line','Station','Status 2','Description', 'Location', 'Assigned To','Department 2', \
                             #'Planned Start','Raised Date','Actual Completion Date / Time']][0:row]
    

dfComplete = dfWithLocation
dfComplete.head()
# Out:
# New No. of Rows:55324
# New No. of Columns:32
#        WO       Status                                        Description  \
# 0  252276    Scheduled    Weekly Legionella Prevention Checklist West Bay
# 1  252275    Scheduled       Weekly Legionella Prevention Checklist WAKRA
# 2  252274  In Progress  Weekly Legionella Prevention Checklist Umma Gh...
# 3  252273    Scheduled         Weekly Legionella Prevention Checklist RBF
# 4  252272    Scheduled        Weekly Legionella Prevention Checklist OQBA
#
#   Work Type   Assigned To  Priority                          Location  \
# 0       PPM  rln-soft wsb       NaN  ACIFM/M/RED LINE/M001/01/RNST030
# 1       PPM  rls-soft awk       NaN  ACIFM/M/RED LINE/M004/01/RSST070
# 2       PPM  rls-soft umg       NaN  ACIFM/M/RED LINE/M003/01/RSST020
# 3       PPM  rls-soft rbf       NaN  ACIFM/M/RED LINE/M004/01/RSST060
# 4       PPM  rls-soft obn       NaN  ACIFM/M/RED LINE/M003/01/RSST040
#
#   Sign Off Notes  Subject          Task/Work Subject Group  ... Done By  \
# 0            NaN  RNST030        acifm-leg-weekly-west bay  ...     NaN
# 1            NaN  RSST070           acifm-leg-weekly-wakra  ...     NaN
# 2            NaN  RSST020  acifm-leg-weekly-umm ghuwailina  ...     NaN
# 3            NaN  RSST060             acifm-leg-weekly-rbf  ...     NaN
# 4            NaN  RSST040            acifm-leg-weekly-oqba  ...     NaN
#
#                Entered By Status 2  Status 3     Code         Station  \
# 0  Muhammad Khalid Shahab     Open      Open  RNST030        West Bay
# 1  Muhammad Khalid Shahab     Open      Open  RSST070        Al Wakra
# 2  Muhammad Khalid Shahab     Open      Open  RSST020  Umm Ghuwailina
# 3  Muhammad Khalid Shahab     Open      Open  RSST060   Ras Bu Fontas
# 4  Muhammad Khalid Shahab     Open      Open  RSST040  Oqba Ibn Nafie
#
#        Line Frequency         System   Department 2
# 0  Red Line    Weekly  not available  Soft Services
# 1  Red Line    Weekly  not available  Soft Services
# 2  Red Line    Weekly  not available  Soft Services
# 3  Red Line    Weekly  not available  Soft Services
# 4  Red Line    Weekly  not available  Soft Services
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Export to Excel

# %% [markdown]
# #### Comparison from Original File

# %%
row = len(df)
col = len(df.columns)
print("Original No. of Rows:" + str(row))
print("Original No. of Columns:" + str(col))
print("-------------------------------------")
rowN = len(dfWithLocation)
colN = len(dfWithLocation.columns)
print("New No. of Rows:" + str(rowN))
print("New No. of Columns:" + str(colN))
print("-------------------------------------")
rowD = rowN - row
colD = colN - col
print("Difference in No. of Rows:" + str(rowD))
print("Difference in No. of Columns:" + str(colD))
# Out:
# Original No. of Rows:55324
# Original No. of Columns:27
# -------------------------------------
# New No. of Rows:55324
# New No. of Columns:32
# -------------------------------------
# Difference in No. of Rows:0
# Difference in No. of Columns:5

# %%
#dfComplete.to_excel("PPM output.xlsx")

# %% [markdown]
# # -------------------------------------- Done ------------------------------------
